# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load data

contracts = pd.read_csv('contracts.csv')

contracts
# Out:
#                       Name  Age   Position Team Contract Start Date  \
# 0           Tristan Luneau   19         RD  ANA        Sep. 5, 2023
# 1             Alex Stalock   35          G  ANA        Aug. 7, 2023
# 2               Troy Terry   25         RW  ANA        Aug. 2, 2023
# 3              Noah Warren   18         RD  ANA       Jul. 19, 2023
# 4             Lukas Dostal   23          G  ANA       Jul. 16, 2023
# ...                    ...  ...        ...  ...                 ...
# 13945  Johnathan Kovacevic   23         RD  WPG       Aug. 12, 2021
# 13946          Andrew Copp   26  C, LW, RW  WPG       Aug. 12, 2021
# 13947           Neal Pionk   25         RD  WPG       Aug. 11, 2021
# 13948        Logan Stanley   23         LD  WPG        Aug. 4, 2021
# 13949      Austin Poganski   25         RW  WPG       Jul. 31, 2021
#
#       Contract Type NHL Clause Way Clause  Term  Total Value         AAV
# 0               ELC        NaN      2-way     3   $2,850,000    $896,667
# ...

# %%
contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13950 entries, 0 to 13949
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 13950 non-null  object
#  1   Age                  13950 non-null  int64
#  2   Position             13950 non-null  object
#  3   Team                 13950 non-null  object
#  4   Contract Start Date  13950 non-null  object
#  5   Contract Type        13950 non-null  object
#  6   NHL Clause           3248 non-null   object
#  7   Way Clause           13950 non-null  object
#  8   Term                 13950 non-null  int64
#  9   Total Value          13950 non-null  object
#  10  AAV                  13950 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB

# %%
contracts['Way Clause'].value_counts()
# Out:
# 2-way    8283
# 1-way    5667
# Name: Way Clause, dtype: int64

# %%
# Drop every contract besides 1-way

contracts = contracts[contracts['Way Clause'] == '1-way']

contracts.drop('Way Clause', axis = 1, inplace=True)

contracts.reset_index(inplace=True)

contracts.drop('index', axis=1, inplace=True)

contracts
# Out:
# /Users/bdogellis/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                 Name  Age   Position Team Contract Start Date Contract Type  \
# 0       Alex Stalock   35          G  ANA        Aug. 7, 2023     35+ (UFA)
# 1         Troy Terry   25         RW  ANA        Aug. 2, 2023    Stnd (RFA)
# 2        Robert Hägg   28         LD  ANA        Jul. 4, 2023    Stnd (UFA)
# 3        Radko Gudas   33         RD  ANA        Jul. 1, 2023    Stnd (UFA)
# 4       Alex Killorn   33     RW, LW  ANA        Jul. 1, 2023    Stnd (UFA)
# ...              ...  ...        ...  ...                 ...           ...
# 5662  Jansen Harkins   25      LW, C  WPG       Jul. 16, 2022    Stnd (RFA)
# ...

# %%
contracts['Contract Start Date'] = pd.to_datetime(contracts['Contract Start Date'])

contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667 entries, 0 to 5666
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 5667 non-null   object
#  1   Age                  5667 non-null   int64
#  2   Position             5667 non-null   object
#  3   Team                 5667 non-null   object
#  4   Contract Start Date  5667 non-null   datetime64[ns]
#  5   Contract Type        5667 non-null   object
#  6   NHL Clause           2052 non-null   object
#  7   Term                 5667 non-null   int64
#  8   Total Value          5667 non-null   object
#  9   AAV                  5667 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 442.9+ KB
# <ipython-input-34-496fb07f8453>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
contracts['Name'].nunique()
# Out:
# 578

# %%
contracts['Name'].value_counts()
# Out:
# Mattias Janmark       27
# Jimmy Vesey           27
# Ilya Samsonov         27
# Erik Gustafsson       27
# Andreas Athanasiou    20
#                       ..
# Jimmy Howard           1
# Clayton Stoner         1
# Valtteri Filppula      1
# Sheldon Souray         1
# Kyle Palmieri          1
# Name: Name, Length: 578, dtype: int64

# %%
eGustafsson = contracts[contracts['Name'] == 'Erik Gustafsson']

eGustafsson
# Out:
#                  Name  Age Position Team Contract Start Date Contract Type  \
# 1027  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1049  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1071  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1093  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1115  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1137  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1159  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1181  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 1203  Erik Gustafsson   29       LD  CHI          2021-10-12    Stnd (UFA)
# 3315  Erik Gustafsson   31       LD  NYR          2023-07-01    Stnd (UFA)
# 3340  Erik Gustafsson   31       LD  NYR          2023-07-01    Stnd (UFA)
# ...

# %% [markdown]
# There are many duplicates in this dataset
